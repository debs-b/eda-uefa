# %% [markdown]
# # Execício Análise dados UEFA EURO

# %%
# Fonte dos dados (Kaggle): https://www.kaggle.com/datasets/piterfm/football-soccer-uefa-euro-1960-2024

# %%
import kagglehub
import os
import pandas as pd
import glob
import matplotlib.pyplot as plt

# %%
# Definir o ID do repositório no Kaggle
repo_id = "piterfm/football-soccer-uefa-euro-1960-2024"

# O kagglehub baixa e faz o cache dos dados automaticamente!
caminho_dataset = kagglehub.dataset_download(repo_id)
print(f"Dataset pronto e cacheado em: {caminho_dataset}")
# Out:
# Dataset pronto e cacheado em: /home/debs/.cache/kagglehub/datasets/piterfm/football-soccer-uefa-euro-1960-2024/versions/13

# %%
# Célula substituída pela integração com o Hugging Face

# %%
files = os.listdir(caminho_dataset)
files
# Out:
# ['logos',
#  'matches',
#  'euro_lineups.csv',
#  'euro_coaches.csv',
#  'euro_summary.csv']

# %%
# Definir o caminho para os CSVs dentro da pasta euro
euro_path = os.path.join(caminho_dataset, "matches", "matches", "euro")

# Listar os arquivos CSV na pasta especificada
try:
    euro_files = [f for f in os.listdir(euro_path) if f.endswith('.csv')]
    euro_files
except FileNotFoundError as e:
    print(f"Pasta não encontrada: {e}")
    euro_files = []


euro_files
# Out:
# ['1980.csv',
#  '2012.csv',
#  '1976.csv',
#  '2004.csv',
#  '1964.csv',
#  '2020.csv',
#  '1988.csv',
#  '1972.csv',
#  '2016.csv',
#  '2008.csv',
#  '1996.csv',
#  '1984.csv',
#  '1992.csv',
#  '2000.csv',
#  '1968.csv',
#  '2024.csv',
#  '1960.csv']

# %%
# Carregando todos os arquivos em um único dataset para análise de dados


# Usar glob para localizar todos os arquivos CSV na pasta especificada
csv_files = glob.glob(os.path.join(caminho_dataset, "matches", "matches", "euro", "*.csv"))

# Carregar todos os arquivos CSV em um único DataFrame
dataframes = []
for file in csv_files:
    try:
        df = pd.read_csv(file)
        dataframes.append(df)
    except Exception as e:
        print(f"Erro ao carregar {file}: {e}")

# Concatenar todos os DataFrames em um único DataFrame
if dataframes:
    euro_data = pd.concat(dataframes, ignore_index=True)
    print("Dados carregados com sucesso!")
    euro_data.head()
else:
    print("Nenhum arquivo foi carregado.")
# Out:
# Dados carregados com sucesso!

# %%
euro_data.head(5)
# Out:
#    id_match       home_team     away_team home_team_code away_team_code  \
# 0      3585         Belgium  West Germany            BEL            FRG
# 1      3584  Czechoslovakia         Italy            TCH            ITA
# 2      3583           Italy       Belgium            ITA            BEL
# 3      3582           Spain       England            ESP            ENG
# 4      3577          Greece  West Germany            GRE            FRG
#
#    home_score  away_score  home_penalty  away_penalty  home_score_total  ...  \
# 0         1.0         2.0           NaN           NaN               1.0  ...
# 1         1.0         1.0           9.0           8.0               1.0  ...
# 2         0.0         0.0           NaN           NaN               0.0  ...
# 3         1.0         2.0           NaN           NaN               1.0  ...
# 4         0.0         0.0           NaN           NaN               0.0  ...
#
#                     stadium_name             stadium_name_media  \
# 0                Stadio Olimpico                Stadio Olimpico
# 1  Stadio Diego Armando Maradona  Stadio Diego Armando Maradona
# 2                Stadio Olimpico                Stadio Olimpico
# 3  Stadio Diego Armando Maradona  Stadio Diego Armando Maradona
# 4                     Delle Alpi                     Delle Alpi
#
#            stadium_name_official             stadium_name_event  \
# 0                Stadio Olimpico               Olimpico in Rome
# 1  Stadio Diego Armando Maradona  Stadio Diego Armando Maradona
# 2                Stadio Olimpico               Olimpico in Rome
# 3  Stadio Diego Armando Maradona  Stadio Diego Armando Maradona
# 4                     Delle Alpi                     Delle Alpi
#
#             stadium_name_sponsor  \
# 0                Stadio Olimpico
# 1  Stadio Diego Armando Maradona
# 2                Stadio Olimpico
# 3  Stadio Diego Armando Maradona
# 4                     Delle Alpi
#
#                                         home_lineups  \
# 0  [{'country_code': 'BEL', 'name': 'Jean-Marie P...
# 1  [{'country_code': 'TCH', 'name': 'Miroslav Gaj...
# 2  [{'country_code': 'ITA', 'name': 'Giuseppe Bar...
# 3  [{'country_code': 'ESP', 'name': 'Dani', 'name...
# 4  [{'country_code': 'GRE', 'name': 'Giorgos Koud...
#
#                                         away_lineups  \
# 0  [{'country_code': 'GER', 'name': 'Bernhard Cul...
# 1  [{'country_code': 'ITA', 'name': 'Romeo Benett...
# 2  [{'country_code': 'BEL', 'name': 'René Verheye...
# 3  [{'country_code': 'ENG', 'name': 'Paul Mariner...
# 4  [{'country_code': 'GER', 'name': 'Miroslav Vot...
#
#                                         home_coaches  \
# 0  [{'country_code': 'BEL', 'country': 'Belgium',...
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4                                                 []
#
#                                         away_coaches  \
# 0  [{'country_code': 'GER', 'country': 'Germany',...
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4                                                 []
#
#                                               events
# 0  [{'id': '53867', 'phase': 'SECOND_HALF', 'type...
# 1  [{'id': '11938', 'phase': 'PENALTY', 'type': '...
# 2  [{'id': '81526', 'phase': 'SECOND_HALF', 'type...
# 3  [{'id': '81256', 'phase': 'SECOND_HALF', 'type...
# 4  [{'id': '81521', 'phase': 'SECOND_HALF', 'type...
#
# [5 rows x 52 columns]

# %%
# Vamos ajustar a configuração do pandas?

pd.set_option('display.max_rows', None)  # Exibir todas as linhas
pd.set_option('display.max_columns', None)  # Exibir todas as colunas
pd.set_option('display.width', None)  # Ajustar a largura para não cortar dados
pd.set_option('display.colheader_justify', 'center')  # Justificar os cabeçalhos

# colocar esse código logo depois de dar 'import pandas as pd' em outros projetos! Ajuda a não esquecer

# %%
euro_data.head(5)
# Out:
#    id_match    home_team      away_team   home_team_code away_team_code  \
# 0    3585           Belgium  West Germany       BEL            FRG
# 1    3584    Czechoslovakia         Italy       TCH            ITA
# 2    3583             Italy       Belgium       ITA            BEL
# 3    3582             Spain       England       ESP            ENG
# 4    3577            Greece  West Germany       GRE            FRG
#
#    home_score  away_score  home_penalty  away_penalty  home_score_total  \
# 0      1.0         2.0          NaN           NaN             1.0
# 1      1.0         1.0          9.0           8.0             1.0
# 2      0.0         0.0          NaN           NaN             0.0
# 3      1.0         2.0          NaN           NaN             1.0
# 4      0.0         0.0          NaN           NaN             0.0
#
#    away_score_total      winner       winner_reason    year     date     \
# 0         2.0          West Germany       WIN_REGULAR  1980  1980-06-22
# 1         1.0        Czechoslovakia  WIN_ON_PENALTIES  1980  1980-06-21
# 2         0.0                   NaN              DRAW  1980  1980-06-18
# 3         2.0               England       WIN_REGULAR  1980  1980-06-18
# 4         0.0                   NaN              DRAW  1980  1980-06-17
#
#         date_time        utc_offset_hours group_name matchday_name  \
# 0  1980-06-22T18:30:00Z         2.0             NaN         1
# 1  1980-06-21T18:30:00Z         2.0             NaN         1
# 2  1980-06-18T18:30:00Z         2.0         Group 2         1
# 3  1980-06-18T15:45:00Z         2.0         Group 2         1
# 4  1980-06-17T18:30:00Z         2.0         Group 1         1
#
#    condition_humidity condition_pitch  condition_temperature  \
# 0         NaN                NaN               NaN
# 1         NaN                NaN               NaN
# 2         NaN                NaN               NaN
# 3         NaN                NaN               NaN
# 4         NaN                NaN               NaN
#
#   condition_weather  condition_wind_speed   status      type      \
# 0         NaN                NaN           FINISHED       SINGLE
# 1         NaN                NaN           FINISHED       SINGLE
# 2         NaN                NaN           FINISHED  GROUP_STAGE
# 3         NaN                NaN           FINISHED  GROUP_STAGE
# 4         NaN                NaN           FINISHED  GROUP_STAGE
#
#        round       round_mode  match_attendance  stadium_id  \
# 0            FINAL      FINAL       47860.0         57775
# 1   THIRD_PLAY_OFF  KNOCK_OUT       24652.0         62425
# 2  GROUP_STANDINGS      GROUP       42318.0         57775
# 3  GROUP_STANDINGS      GROUP       14440.0         62425
# 4  GROUP_STANDINGS      GROUP       13901.0         57778
#
#   stadium_country_code  stadium_capacity  stadium_latitude  stadium_longitude  \
# 0          ITA               69689.0          41.933922         12.454683
# 1          ITA               54726.0          40.828089         14.192869
# 2          ITA               69689.0          41.933922         12.454683
# 3          ITA               54726.0          40.828089         14.192869
# 4          ITA               66979.0          45.109547          7.641281
#
#    stadium_pitch_length  stadium_pitch_width  \
# 0          105.0                68.0
# 1          105.0                68.0
# 2          105.0                68.0
# 3          105.0                68.0
# 4          105.0                68.0
#
#                         goals                        penalties_missed  \
# 0  [{'phase': 'FIRST_HALF', 'time': {'minute': 10...        NaN
# 1  [{'phase': 'SECOND_HALF', 'time': {'minute': 5...        NaN
# 2                                                NaN        NaN
# 3  [{'phase': 'FIRST_HALF', 'time': {'minute': 19...        NaN
# 4                                                NaN        NaN
#
#                       penalties                      red_cards game_referees  \
# 0                                                NaN     NaN         []
# 1  [{'phase': 'PENALTY', 'time': {}, 'internation...     NaN         []
# 2                                                NaN     NaN         []
# 3                                                NaN     NaN         []
# 4                                                NaN     NaN         []
#
#   stadium_city          stadium_name                stadium_name_media        \
# 0      Rome                   Stadio Olimpico                Stadio Olimpico
# 1    Naples     Stadio Diego Armando Maradona  Stadio Diego Armando Maradona
# 2      Rome                   Stadio Olimpico                Stadio Olimpico
# 3    Naples     Stadio Diego Armando Maradona  Stadio Diego Armando Maradona
# 4     Turin                        Delle Alpi                     Delle Alpi
#
#       stadium_name_official            stadium_name_event        \
# 0                Stadio Olimpico               Olimpico in Rome
# 1  Stadio Diego Armando Maradona  Stadio Diego Armando Maradona
# 2                Stadio Olimpico               Olimpico in Rome
# 3  Stadio Diego Armando Maradona  Stadio Diego Armando Maradona
# 4                     Delle Alpi                     Delle Alpi
#
#        stadium_name_sponsor       \
# 0                Stadio Olimpico
# 1  Stadio Diego Armando Maradona
# 2                Stadio Olimpico
# 3  Stadio Diego Armando Maradona
# 4                     Delle Alpi
#
#                      home_lineups                     \
# 0  [{'country_code': 'BEL', 'name': 'Jean-Marie P...
# 1  [{'country_code': 'TCH', 'name': 'Miroslav Gaj...
# 2  [{'country_code': 'ITA', 'name': 'Giuseppe Bar...
# 3  [{'country_code': 'ESP', 'name': 'Dani', 'name...
# 4  [{'country_code': 'GRE', 'name': 'Giorgos Koud...
#
#                      away_lineups                     \
# 0  [{'country_code': 'GER', 'name': 'Bernhard Cul...
# 1  [{'country_code': 'ITA', 'name': 'Romeo Benett...
# 2  [{'country_code': 'BEL', 'name': 'René Verheye...
# 3  [{'country_code': 'ENG', 'name': 'Paul Mariner...
# 4  [{'country_code': 'GER', 'name': 'Miroslav Vot...
#
#                      home_coaches                     \
# 0  [{'country_code': 'BEL', 'country': 'Belgium',...
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4                                                 []
#
#                      away_coaches                     \
# 0  [{'country_code': 'GER', 'country': 'Germany',...
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4                                                 []
#
#                         events
# 0  [{'id': '53867', 'phase': 'SECOND_HALF', 'type...
# 1  [{'id': '11938', 'phase': 'PENALTY', 'type': '...
# 2  [{'id': '81526', 'phase': 'SECOND_HALF', 'type...
# 3  [{'id': '81256', 'phase': 'SECOND_HALF', 'type...
# 4  [{'id': '81521', 'phase': 'SECOND_HALF', 'type...

# %%
len(euro_data)
# Out:
# 388

# %%
len(euro_data.columns)
# Out:
# 52

# %%
euro_data.columns
# Out:
# Index(['id_match', 'home_team', 'away_team', 'home_team_code',
#        'away_team_code', 'home_score', 'away_score', 'home_penalty',
#        'away_penalty', 'home_score_total', 'away_score_total', 'winner',
#        'winner_reason', 'year', 'date', 'date_time', 'utc_offset_hours',
#        'group_name', 'matchday_name', 'condition_humidity', 'condition_pitch',
#        'condition_temperature', 'condition_weather', 'condition_wind_speed',
#        'status', 'type', 'round', 'round_mode', 'match_attendance',
#        'stadium_id', 'stadium_country_code', 'stadium_capacity',
#        'stadium_latitude', 'stadium_longitude', 'stadium_pitch_length',
#        'stadium_pitch_width', 'goals', 'penalties_missed', 'penalties',
#        'red_cards', 'game_referees', 'stadium_city', 'stadium_name',
#        'stadium_name_media', 'stadium_name_official', 'stadium_name_event',
#        'stadium_name_sponsor', 'home_lineups', 'away_lineups', 'home_coaches',
#        'away_coaches', 'events'],
#       dtype='object')

# %% [markdown]
# # Análise Valores Nulos

# %%
valores_nulos = euro_data.isnull().sum()
valores_nulos
# Out:
# id_match                   0
# home_team                  0
# away_team                  0
# home_team_code             0
# away_team_code             0
# home_score                 0
# away_score                 0
# home_penalty             363
# away_penalty             363
# home_score_total           0
# away_score_total           0
# winner                    77
# winner_reason              0
# year                       0
# date                       0
# date_time                  0
# utc_offset_hours           0
# group_name               112
# matchday_name              0
# condition_humidity       202
# condition_pitch          211
# condition_temperature    202
# condition_weather        203
# condition_wind_speed     202
# status                     0
# type                       0
# round                      0
# round_mode                 0
# match_attendance           0
# stadium_id                 0
# stadium_country_code       0
# stadium_capacity           0
# stadium_latitude           0
# stadium_longitude          0
# stadium_pitch_length       0
# stadium_pitch_width        0
# goals                     36
# penalties_missed         372
# penalties                363
# red_cards                345
# game_referees              0
# stadium_city               0
# stadium_name               0
# stadium_name_media         0
# stadium_name_official      0
# stadium_name_event         0
# stadium_name_sponsor       5
# home_lineups               0
# away_lineups               0
# home_coaches               0
# away_coaches               0
# events                     1
# dtype: int64

# %% [markdown]
# ## O que podemos observar baseado nas colunas que estão nulas?

# %%
valores_nulos_totais = valores_nulos[valores_nulos > 0]
valores_nulos_totais
# Out:
# home_penalty             363
# away_penalty             363
# winner                    77
# group_name               112
# condition_humidity       202
# condition_pitch          211
# condition_temperature    202
# condition_weather        203
# condition_wind_speed     202
# goals                     36
# penalties_missed         372
# penalties                363
# red_cards                345
# stadium_name_sponsor       5
# events                     1
# dtype: int64

# %% [markdown]
# ### Penaltis faz sentido;
# ### Winner tbm, por causa dos empates;
# ### alem da fase de grupos, nao tem mais grupo;
# ### condicoes climaticas --> o pessoal ficou com preguica de anotar, normal;
# ### gols tbm faz sentido, por causa das partidas de 0x0;
# ...

# %%
registros_duplicados = euro_data.duplicated().sum()
registros_duplicados
# Out:
# np.int64(0)

# %% [markdown]
# # Análise Estatística

# %%
# Listar as colunas por tipo de dado

# Colunas categóricas
colunas_categoricas = euro_data.select_dtypes(include=['object']).columns.tolist()
print("Colunas categóricas:")
print(colunas_categoricas)

# Colunas numéricas
colunas_numericas = euro_data.select_dtypes(include=['number']).columns.tolist()
print("\nColunas numéricas:")
print(colunas_numericas)

# Colunas de data/hora
# Deixando aqui como exemplo para futuras análises
colunas_datahora = euro_data.select_dtypes(include=['datetime']).columns.tolist()
print("\nColunas de data/hora:")
print(colunas_datahora)
# Out:
# Colunas categóricas:
# ['home_team', 'away_team', 'home_team_code', 'away_team_code', 'winner', 'winner_reason', 'date', 'date_time', 'group_name', 'matchday_name', 'condition_pitch', 'condition_weather', 'status', 'type', 'round', 'round_mode', 'stadium_country_code', 'goals', 'penalties_missed', 'penalties', 'red_cards', 'game_referees', 'stadium_city', 'stadium_name', 'stadium_name_media', 'stadium_name_official', 'stadium_name_event', 'stadium_name_sponsor', 'home_lineups', 'away_lineups', 'home_coaches', 'away_coaches', 'events']
#
# Colunas numéricas:
# ['id_match', 'home_score', 'away_score', 'home_penalty', 'away_penalty', 'home_score_total', 'away_score_total', 'year', 'utc_offset_hours', 'condition_humidity', 'condition_temperature', 'condition_wind_speed', 'match_attendance', 'stadium_id', 'stadium_capacity', 'stadium_latitude', 'stadium_longitude', 'stadium_pitch_length', 'stadium_pitch_width']
#
# Colunas de data/hora:
# []

# %%
# País mais vencedor

# %%
vencedores = euro_data['winner'].value_counts()
print("Times mais vencedores da EURO (número de vitórias):")
print(vencedores)
print(f"\nTime mais vencedor: {vencedores.idxmax()} com {vencedores.max()} vitórias.")
# Out:
# Times mais vencedores da EURO (número de vitórias):
# winner
# Spain                  32
# Italy                  26
# France                 25
# Portugal               24
# Netherlands            24
# Germany                23
# England                20
# Czechia                13
# Belgium                12
# Denmark                11
# Croatia                 9
# West Germany            9
# Türkiye                 8
# USSR                    7
# Sweden                  7
# Russia                  6
# Switzerland             6
# Czechoslovakia          5
# Wales                   5
# Greece                  5
# Austria                 4
# Ukraine                 4
# Hungary                 3
# Slovakia                3
# Poland                  3
# Yugoslavia              3
# Republic of Ireland     2
# Iceland                 2
# Romania                 2
# Scotland                2
# Finland                 1
# Albania                 1
# Bulgaria                1
# Northern Ireland        1
# Norway                  1
# Georgia                 1
# Name: count, dtype: int64
#
# Time mais vencedor: Spain com 32 vitórias.

# %% [markdown]
# ### fui checar online, e Espanha realmente tem mais titulos, com 4.
# ### Seguida por Alemanha, 3;  Italia 2; Franca 2....

# %%
# Distribuição de gols por partida

# %%
euro_data['total_goals'] = euro_data['home_score'] + euro_data['away_score']

# Calcular a média de gols
media_gols = euro_data['total_goals'].mean()

# Plotar a distribuição com a média destacada
plt.figure(figsize=(10, 6))
max_goals = int(euro_data['total_goals'].max()) + 1  # Garantir que o limite seja um inteiro
plt.hist(euro_data['total_goals'], bins=range(0, max_goals + 1), edgecolor='black', alpha=0.7, color='blue')
plt.axvline(media_gols, color='red', linestyle='dashed', linewidth=2, label=f'Média: {media_gols:.2f}')
plt.title("Distribuição do Número de Gols por Partida", fontsize=14)
plt.xlabel("Número de Gols", fontsize=12)
plt.ylabel("Frequência", fontsize=12)
plt.legend(fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
# Calcular a média de gols por ano
media_gols_por_ano = euro_data.groupby('year')['total_goals'].mean()

# Plotar a tendência da média de gols ao longo do tempo
plt.figure(figsize=(12, 6))
plt.plot(media_gols_por_ano.index, media_gols_por_ano.values, marker='o', linestyle='-', color='blue')
plt.title("Evolução da Média de Gols por Partida ao Longo do Tempo", fontsize=14)
plt.xlabel("Ano", fontsize=12)
plt.ylabel("Média de Gols por Partida", fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.xticks(media_gols_por_ano.index, rotation=45)
plt.show()

print("Média de gols por ano:")
print(media_gols_por_ano)
# Out:
# Média de gols por ano:
# year
# 1960    4.000000
# 1964    2.500000
# 1968    1.400000
# 1972    2.500000
# 1976    3.500000
# 1980    1.928571
# 1984    2.400000
# 1988    2.266667
# 1992    2.133333
# 1996    2.032258
# 2000    2.677419
# 2004    2.387097
# 2008    2.354839
# 2012    2.451613
# 2016    2.078431
# 2020    2.647059
# 2024    2.254902
# Name: total_goals, dtype: float64

# %% [markdown]
# ## Comentário gráficos temporais

# %% [markdown]
# ## Quais conclusões podemos tirar desses valores?

# %% [markdown]
# ### Por exemplo, que o futebol tem se estabilizado com o tempo, mais iguadade na qualidade dos times. Bias

# %%
# Determinar os vencedores finais da competição (um por ano): o vencedor da final
# (ignora o jogo empatado de 1968, que foi decidido no jogo de desempate)
finais_decididas = euro_data[(euro_data['round'] == 'FINAL') & euro_data['winner'].notna()]
vencedores_competicao = finais_decididas.set_index('year')['winner'].sort_index()
vencedores_competicao
# Out:
# year
# 1960              USSR
# 1964             Spain
# 1968             Italy
# 1972      West Germany
# 1976    Czechoslovakia
# 1980      West Germany
# 1984            France
# 1988       Netherlands
# 1992           Denmark
# 1996           Germany
# 2000            France
# 2004            Greece
# 2008             Spain
# 2012             Spain
# 2016          Portugal
# 2020             Italy
# 2024             Spain
# Name: winner, dtype: object

# %%
# Contar o número de títulos por time
titulos_por_time = vencedores_competicao.value_counts()
titulos_por_time
# Out:
# winner
# Spain             4
# Italy             2
# West Germany      2
# France            2
# USSR              1
# Czechoslovakia    1
# Netherlands       1
# Denmark           1
# Germany           1
# Greece            1
# Portugal          1
# Name: count, dtype: int64

# %%
# Criar o gráfico de barras para visualizar os times com mais títulos
plt.figure(figsize=(12, 6))
titulos_por_time.plot(kind='bar', color='skyblue', edgecolor='black')
plt.title("Número de Títulos por Time na EURO", fontsize=14)
plt.xlabel("Times", fontsize=12)
plt.ylabel("Número de Títulos", fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
# Gráfico ajustado com os anos de título na horizontal, empilhados com espaço entre eles
plt.figure(figsize=(12, 6))

# Criar o gráfico de barras
bars = plt.bar(titulos_por_time.index, titulos_por_time.values, color='skyblue', edgecolor='black')

# Adicionar os anos de vitória em cada barra, empilhados com espaço
for bar, country in zip(bars, titulos_por_time.index):
    anos_vitoria = vencedores_competicao[vencedores_competicao == country].index.tolist()
    for i, ano in enumerate(anos_vitoria):
        plt.text(
            bar.get_x() + bar.get_width() / 2,  # Posição central da barra
            i * 0.25 + 0.1,  # Espaço vertical entre os anos
            str(ano),
            ha='center', va='bottom', fontsize=10, rotation=0  # Texto na horizontal
        )

# Ajustar o gráfico
plt.title("Número de Títulos por País na EURO", fontsize=14)
plt.xlabel("País", fontsize=12)
plt.ylabel("Número de Títulos", fontsize=12)
plt.xticks(rotation=45, fontsize=10)
plt.tight_layout()

# Exibir o gráfico
plt.show()

# %%
import matplotlib.pyplot as plt

# Verificar se a coluna de público está presente no DataFrame
if 'match_attendance' in euro_data.columns:
    # Distribuição do público (histograma)
    plt.figure(figsize=(12, 6))
    plt.hist(euro_data['match_attendance'].dropna(), bins=20, color='skyblue', edgecolor='black', alpha=0.7)
    plt.title("Distribuição do Público nas Partidas da EURO", fontsize=14)
    plt.xlabel("Público", fontsize=12)
    plt.ylabel("Frequência", fontsize=12)
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.tight_layout()
    plt.show()

    # Média de público por ano
    publico_por_ano = euro_data.groupby('year')['match_attendance'].mean()
    plt.figure(figsize=(12, 6))
    plt.plot(publico_por_ano.index, publico_por_ano.values, marker='o', linestyle='-', color='blue')
    plt.title("Média de Público por Ano na EURO", fontsize=14)
    plt.xlabel("Ano", fontsize=12)
    plt.ylabel("Média de Público", fontsize=12)
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.xticks(publico_por_ano.index, rotation=45)
    plt.tight_layout()
    plt.show()

    # Partidas com maior público
    maior_publico = euro_data.nlargest(10, 'match_attendance')
    plt.figure(figsize=(12, 6))
    plt.barh(
        [f"{row['home_team']} vs {row['away_team']} ({row['year']})" for _, row in maior_publico.iterrows()],
        maior_publico['match_attendance'],
        color='skyblue',
        edgecolor='black'
    )
    plt.title("Top 10 Partidas com Maior Público na EURO", fontsize=14)
    plt.xlabel("Público", fontsize=12)
    plt.ylabel("Partidas", fontsize=12)
    plt.tight_layout()
    plt.show()
else:
    print("A coluna 'match_attendance' não está presente no DataFrame.")

# %%
# Verificar se a coluna de público está presente no DataFrame
if {'match_attendance', 'stadium_country_code'}.issubset(euro_data.columns):
    # Média de público por ano
    publico_por_ano = euro_data.groupby('year')['match_attendance'].mean()

    # País(es) sede por ano: juntar todos os países com estádios naquele ano
    # (ex.: 2000 BEL/NED; 2020 foi em vários países)
    def paises_sede(codigos):
        paises = sorted(codigos.dropna().unique())
        return '/'.join(paises) if len(paises) <= 3 else f"Vários ({len(paises)})"
    pais_sede_por_ano = euro_data.groupby('year')['stadium_country_code'].agg(paises_sede)

    # Criar o gráfico de média de público com o país sede
    plt.figure(figsize=(12, 6))
    plt.plot(publico_por_ano.index, publico_por_ano.values, marker='o', linestyle='-', color='blue', label="Média de Público")
    
    # Adicionar o país sede como rótulo
    for year, attendance in publico_por_ano.items():
        host_country = pais_sede_por_ano.get(year, "Desconhecido")
        plt.text(year, attendance + 1000, host_country, fontsize=9, ha='center', va='bottom', color='darkred')

    # Ajustar o gráfico
    plt.title("Média de Público por Ano na EURO (com País Sede)", fontsize=14)
    plt.xlabel("Ano", fontsize=12)
    plt.ylabel("Média de Público", fontsize=12)
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.xticks(publico_por_ano.index, rotation=45)
    plt.legend(fontsize=10)
    plt.tight_layout()
    plt.show()
else:
    print("A coluna 'match_attendance' ou 'stadium_country_code' não está presente no DataFrame.")

# %% [markdown]
# #### sistema de turismo da alemanha

# %% [markdown]
# ### 1980 escandalo sobre partidas fixas na italia: https://en.wikipedia.org/wiki/1980_Totonero
# ### 1976: Yuguslavia pais socialista, pouco acesso
# ### 1972 Recessão de 1973-1975: https://www.statista.com/topics/8095/the-1973-1975-recession/

# %%
# 1980 escandalo sobre partidas fixas na italia: https://en.wikipedia.org/wiki/1980_Totonero
# 1976: Yuguslavia pais socialista, pouco acesso 
# 1972 Recessão de 1973-1975: https://www.statista.com/topics/8095/the-1973-1975-recession/

# %% [markdown]
# ### Dados contam histórias. É nosso trabalho como cientistas de dados encontrar e contar essas histórias

# %% [markdown]
# # Análise cartões vermelhos

# %%
# Na coluna de red_cards, há dicionários! Uma estrutura mais complexa para estrair os dados. Mas vamos lá!
valores_unicos = euro_data['red_cards'].unique()
print("Valores únicos na coluna 'red_cards':")
print(valores_unicos)
# Out:
# Valores únicos na coluna 'red_cards':
# [nan
#  "[{'phase': 'SECOND_HALF', 'time': {'minute': 89, 'second': 25}, 'international_name': 'Keith Andrews', 'club_shirt_name': 'Andrews', 'country_code': 'IRL', 'national_field_position': '', 'national_jersey_number': '8'}]"
#  "[{'phase': 'FIRST_HALF', 'time': {'minute': 44, 'second': 43}, 'international_name': 'Sokratis Papastathopoulos', 'club_shirt_name': 'Sokratis', 'country_code': 'GRE', 'national_field_position': 'DEFENDER', 'national_jersey_number': '19'}, {'phase': 'SECOND_HALF', 'time': {'minute': 69, 'second': 17}, 'international_name': 'Wojciech Szczęsny', 'club_shirt_name': 'Szczęsny', 'country_code': 'POL', 'national_field_position': 'GOALKEEPER', 'national_jersey_number': '1'}]"
#  "[{'phase': 'SECOND_HALF', 'time': {'minute': 60, 'second': 0}, 'international_name': 'Jaroslav Pollák', 'club_shirt_name': 'Pollák', 'country_code': 'TCH', 'national_field_position': 'MIDFIELDER', 'national_jersey_number': None}, {'phase': 'SECOND_HALF', 'time': {'minute': 76, 'second': 0}, 'international_name': 'Johan Neeskens', 'club_shirt_name': 'Neeskens', 'country_code': 'NED', 'national_field_position': 'MIDFIELDER', 'national_jersey_number': None}, {'phase': 'EXTRA_TIME_SECOND_HALF', 'time': {'minute': 115, 'second': 0}, 'international_name': 'Wim van Hanegem', 'club_shirt_name': 'Van Hanegem', 'country_code': 'NED', 'national_field_position': 'MIDFIELDER', 'national_jersey_number': None}]"
#  "[{'phase': 'SECOND_HALF', 'time': {'minute': 75, 'second': 42}, 'international_name': 'John Heitinga', 'club_shirt_name': '', 'country_code': 'NED', 'national_field_position': 'DEFENDER', 'national_jersey_number': '3'}]"
#  "[{'phase': 'SECOND_HALF', 'time': {'minute': 83, 'second': 32}, 'international_name': 'Stiliyan Petrov', 'club_shirt_name': 'Petrov', 'country_code': 'BUL', 'national_field_position': 'MIDFIELDER', 'national_jersey_number': '19'}]"
#  "[{'phase': 'SECOND_HALF', 'time': {'minute': 60, 'second': 30}, 'international_name': 'Bernt Haas', 'club_shirt_name': '', 'country_code': 'SUI', 'national_field_position': '', 'national_jersey_number': None}]"
#  "[{'phase': 'FIRST_HALF', 'time': {'minute': 45, 'second': 27}, 'international_name': 'Sergei Ovchinnikov', 'club_shirt_name': '', 'country_code': 'RUS', 'national_field_position': '', 'national_jersey_number': None}]"
#  "[{'phase': 'SECOND_HALF', 'time': {'minute': 50, 'second': 35}, 'international_name': 'Johann Vogel', 'club_shirt_name': 'Vogel', 'country_code': 'SUI', 'national_field_position': '', 'national_jersey_number': None}]"
#  "[{'phase': 'SECOND_HALF', 'time': {'minute': 88, 'second': 36}, 'international_name': 'Roman Sharonov', 'club_shirt_name': 'SHARONOV', 'country_code': 'RUS', 'national_field_position': 'DEFENDER', 'national_jersey_number': '3'}]"
#  "[{'phase': 'SECOND_HALF', 'time': {'minute': 77, 'second': 38}, 'international_name': 'Remo Freuler', 'club_shirt_name': 'Freuler', 'country_code': 'SUI', 'national_field_position': 'MIDFIELDER', 'national_jersey_number': '8'}]"
#  "[{'phase': 'EXTRA_TIME_FIRST_HALF', 'time': {'minute': 98, 'second': 12}, 'international_name': 'Marcus Danielson', 'club_shirt_name': 'Danielson', 'country_code': 'SWE', 'national_field_position': 'DEFENDER', 'national_jersey_number': '24'}]"
#  "[{'phase': 'SECOND_HALF', 'time': {'minute': 52, 'second': 33}, 'international_name': 'Matthijs De Ligt', 'club_shirt_name': 'De Ligt', 'country_code': 'NED', 'national_field_position': 'DEFENDER', 'national_jersey_number': '3'}]"
#  "[{'phase': 'SECOND_HALF', 'time': {'minute': 90, 'second': 50}, 'international_name': 'Harry Wilson', 'club_shirt_name': 'Wilson', 'country_code': 'WAL', 'national_field_position': 'MIDFIELDER', 'national_jersey_number': '8'}]"
#  "[{'phase': 'SECOND_HALF', 'time': {'minute': 55, 'second': 57}, 'international_name': 'Ethan Ampadu', 'club_shirt_name': 'Ampadu', 'country_code': 'WAL', 'national_field_position': 'DEFENDER', 'national_jersey_number': '15'}]"
#  "[{'phase': 'SECOND_HALF', 'time': {'minute': 62, 'second': 42}, 'international_name': 'Grzegorz Krychowiak', 'club_shirt_name': 'Krychowiak', 'country_code': 'POL', 'national_field_position': 'MIDFIELDER', 'national_jersey_number': '10'}]"
#  "[{'phase': 'SECOND_HALF', 'time': {'minute': 66, 'second': 25}, 'international_name': 'Shane Duffy', 'club_shirt_name': 'DUFFY', 'country_code': 'IRL', 'national_field_position': 'DEFENDER', 'national_jersey_number': '4'}]"
#  "[{'phase': 'SECOND_HALF', 'time': {'minute': 66, 'second': 22}, 'international_name': 'Aleksandar Dragović', 'club_shirt_name': 'Dragović', 'country_code': 'AUT', 'national_field_position': 'DEFENDER', 'national_jersey_number': '3'}]"
#  "[{'phase': 'FIRST_HALF', 'time': {'minute': 36}, 'international_name': 'Lorik Cana', 'club_shirt_name': 'Cana', 'country_code': 'FRA', 'national_field_position': 'MIDFIELDER', 'national_jersey_number': '5'}]"
#  "[{'phase': 'FIRST_HALF', 'time': {'minute': 24, 'second': 50}, 'international_name': 'Éric Abidal', 'club_shirt_name': 'Abidal', 'country_code': 'FRA', 'national_field_position': 'DEFENDER', 'national_jersey_number': '22'}]"
#  "[{'phase': 'SECOND_HALF', 'time': {'injuryMinute': 2, 'minute': 90, 'second': 35}, 'international_name': 'Volkan Demirel', 'club_shirt_name': 'VOLKAN', 'country_code': 'TUR', 'national_field_position': 'GOALKEEPER', 'national_jersey_number': '1'}]"
#  "[{'phase': 'SECOND_HALF', 'time': {'injuryMinute': 2, 'minute': 90, 'second': 9}, 'international_name': 'Bastian Schweinsteiger', 'club_shirt_name': 'SCHWEINSTEIGER', 'country_code': 'GER', 'national_field_position': 'MIDFIELDER', 'national_jersey_number': '7'}]"
#  "[{'phase': 'SECOND_HALF', 'time': {'minute': 82}, 'international_name': 'Radoslav Látal', 'club_shirt_name': 'Látal', 'country_code': 'CZE', 'national_field_position': 'MIDFIELDER', 'national_jersey_number': None}]"
#  "[{'phase': 'SECOND_HALF', 'time': {'minute': 56, 'second': 0}, 'international_name': 'Igor Štimac', 'club_shirt_name': 'Štimac', 'country_code': 'CRO', 'national_field_position': 'DEFENDER', 'national_jersey_number': None}]"
#  "[{'phase': 'SECOND_HALF', 'time': {'minute': 59, 'second': 0}, 'international_name': 'Thomas Strunz', 'club_shirt_name': 'Strunz', 'country_code': 'GER', 'national_field_position': 'MIDFIELDER', 'national_jersey_number': None}]"
#  "[{'phase': 'SECOND_HALF', 'time': {'minute': 70, 'second': 0}, 'international_name': 'Yuri Kovtun', 'club_shirt_name': 'Kovtun', 'country_code': 'RUS', 'national_field_position': 'DEFENDER', 'national_jersey_number': None}]"
#  "[{'phase': 'FIRST_HALF', 'time': {'minute': 29, 'second': 0}, 'international_name': 'Luigi Apolloni', 'club_shirt_name': 'Apolloni', 'country_code': 'ITA', 'national_field_position': 'DEFENDER', 'national_jersey_number': None}]"
#  "[{'phase': 'SECOND_HALF', 'time': {'minute': 72, 'second': 0}, 'international_name': 'Petar Hubchev', 'club_shirt_name': 'Hubchev', 'country_code': 'BUL', 'national_field_position': '', 'national_jersey_number': None}, {'phase': 'SECOND_HALF', 'time': {'minute': 75, 'second': 0}, 'international_name': 'Juan Antonio Pizzi', 'club_shirt_name': 'Pizzi', 'country_code': 'ESP', 'national_field_position': 'FORWARD', 'national_jersey_number': None}]"
#  "[{'phase': 'SECOND_HALF', 'time': {'minute': 85, 'second': 0}, 'international_name': 'Yvon Le Roux', 'club_shirt_name': 'Le Roux', 'country_code': 'FRA', 'national_field_position': 'DEFENDER', 'national_jersey_number': None}]"
#  "[{'phase': 'EXTRA_TIME_SECOND_HALF', 'time': {'minute': 107, 'second': 0}, 'international_name': 'Klaus Berggreen', 'club_shirt_name': 'Berggreen', 'country_code': 'DEN', 'national_field_position': '', 'national_jersey_number': None}]"
#  "[{'phase': 'SECOND_HALF', 'time': {'minute': 87, 'second': 0}, 'international_name': 'Manuel Amoros', 'club_shirt_name': 'Amoros', 'country_code': 'FRA', 'national_field_position': 'DEFENDER', 'national_jersey_number': None}]"
#  "[{'phase': 'FIRST_HALF', 'time': {'minute': 34, 'second': 0}, 'international_name': 'Gianluca Zambrotta', 'club_shirt_name': 'Zambrotta', 'country_code': 'ITA', 'national_field_position': 'DEFENDER', 'national_jersey_number': '19'}]"
#  "[{'phase': 'SECOND_HALF', 'time': {'minute': 59, 'second': 0}, 'international_name': 'Gheorghe Hagi', 'club_shirt_name': '', 'country_code': 'ROU', 'national_field_position': 'MIDFIELDER', 'national_jersey_number': None}]"
#  "[{'phase': 'FIRST_HALF', 'time': {'minute': 30, 'second': 0}, 'international_name': 'Alpay Özalan', 'club_shirt_name': 'Alpay Özalan', 'country_code': 'TUR', 'national_field_position': 'DEFENDER', 'national_jersey_number': None}]"
#  "[{'phase': 'SECOND_HALF', 'time': {'minute': 63, 'second': 0}, 'international_name': 'Slaviša Jokanović', 'club_shirt_name': '', 'country_code': 'ESP', 'national_field_position': 'MIDFIELDER', 'national_jersey_number': None}]"
#  "[{'phase': 'SECOND_HALF', 'time': {'minute': 84, 'second': 0}, 'international_name': 'Filip De Wilde', 'club_shirt_name': 'de Wilde', 'country_code': 'BEL', 'national_field_position': '', 'national_jersey_number': None}]"
#  "[{'phase': 'SECOND_HALF', 'time': {'minute': 88, 'second': 0}, 'international_name': 'Mateja Kežman', 'club_shirt_name': 'Kezman', 'country_code': 'SRB', 'national_field_position': 'FORWARD', 'national_jersey_number': None}]"
#  "[{'phase': 'SECOND_HALF', 'time': {'minute': 60, 'second': 0}, 'international_name': 'Siniša Mihajlović', 'club_shirt_name': 'Mihajlović', 'country_code': 'SRB', 'national_field_position': 'DEFENDER', 'national_jersey_number': None}]"
#  "[{'phase': 'SECOND_HALF', 'time': {'minute': 81, 'second': 0}, 'international_name': 'Patrik Andersson', 'club_shirt_name': 'Patrick Andersson', 'country_code': 'SWE', 'national_field_position': 'DEFENDER', 'national_jersey_number': None}]"
#  "[{'phase': 'SECOND_HALF', 'time': {'minute': 89}, 'international_name': 'Alan Mullery', 'club_shirt_name': 'Mullery', 'country_code': 'ENG', 'national_field_position': 'MIDFIELDER', 'national_jersey_number': None}]"
#  "[{'phase': 'SECOND_HALF', 'time': {'injuryMinute': 6, 'minute': 90, 'second': 23}, 'international_name': 'Bertuğ Yıldırım', 'club_shirt_name': 'Bertuğ', 'country_code': 'TUR', 'national_field_position': 'FORWARD', 'national_jersey_number': '26'}]"
#  "[{'phase': 'EXTRA_TIME_SECOND_HALF', 'time': {'injuryMinute': 4, 'minute': 120, 'second': 59}, 'international_name': 'Dani Carvajal', 'club_shirt_name': 'CARVAJAL', 'country_code': 'ESP', 'national_field_position': 'DEFENDER', 'national_jersey_number': '2'}]"
#  "[{'phase': 'FIRST_HALF', 'time': {'minute': 20, 'second': 33}, 'international_name': 'Antonín Barák', 'club_shirt_name': 'Barak', 'country_code': 'CZE', 'national_field_position': 'MIDFIELDER', 'national_jersey_number': '7'}, {'phase': 'SECOND_HALF', 'time': {'injuryMinute': 8, 'minute': 90, 'second': 40}, 'international_name': 'Tomáš Chorý', 'club_shirt_name': 'Chorý', 'country_code': 'CZE', 'national_field_position': 'FORWARD', 'national_jersey_number': '19'}]"
#  "[{'phase': 'FIRST_HALF', 'time': {'minute': 44, 'second': 55}, 'international_name': 'Ryan Porteous', 'club_shirt_name': 'Porteous', 'country_code': 'SCO', 'national_field_position': 'DEFENDER', 'national_jersey_number': '15'}]"]

# %%
import ast
from collections import Counter

# %%
# Função para processar a coluna 'red_cards' e extrair informações detalhadas
def processar_cartoes_vermelhos(red_cards_column):
    contador_paises = Counter()
    contador_posicoes = Counter()
    contador_jogadores = Counter()
    
    for entry in red_cards_column:
        if pd.isna(entry):
            continue  # Ignorar NaNs
        
        try:
            # Converter a string em uma lista de dicionários
            cartoes = ast.literal_eval(entry)
            for cartao in cartoes:
                # Contar por país
                country_code = cartao.get('country_code', 'país não informado')
                contador_paises[country_code] += 1
                
                # Contar por posição
                position = cartao.get('national_field_position', 'posição não informada')
                contador_posicoes[position] += 1
                
        except (ValueError, SyntaxError):
            continue  # Ignorar entradas inválidas
    
    return contador_paises, contador_posicoes, contador_jogadores

# %%
euro_data['red_cards'] = euro_data['red_cards'].fillna("[]")  # Substituir NaN por uma lista vazia
cartoes_por_pais, cartoes_por_posicao, cartoes_por_jogador = processar_cartoes_vermelhos(euro_data['red_cards'])

# %%
cartoes_por_pais
# Out:
# Counter({'NED': 4,
#          'FRA': 4,
#          'SUI': 3,
#          'RUS': 3,
#          'TUR': 3,
#          'CZE': 3,
#          'ESP': 3,
#          'IRL': 2,
#          'POL': 2,
#          'BUL': 2,
#          'SWE': 2,
#          'WAL': 2,
#          'GER': 2,
#          'ITA': 2,
#          'SRB': 2,
#          'GRE': 1,
#          'TCH': 1,
#          'AUT': 1,
#          'CRO': 1,
#          'DEN': 1,
#          'ROU': 1,
#          'BEL': 1,
#          'ENG': 1,
#          'SCO': 1})

# %%
euro_data['red_cards'] = euro_data['red_cards'].fillna("[]")  # Substituir NaN por uma lista vazia
cartoes_por_pais, cartoes_por_posicao, cartoes_por_jogador = processar_cartoes_vermelhos(euro_data['red_cards'])

# Transformar os resultados em DataFrames
df_paises = pd.DataFrame.from_dict(cartoes_por_pais, orient='index', columns=['total_red_cards']).sort_values(by='total_red_cards', ascending=False)
df_posicoes = pd.DataFrame.from_dict(cartoes_por_posicao, orient='index', columns=['total_red_cards']).sort_values(by='total_red_cards', ascending=False)


# Criar gráficos diferentes
# Gráfico 1: Cartões por país
df_paises.head(10).plot(kind='bar', figsize=(12, 6), color='red', edgecolor='black', legend=False)
plt.title("Top 10 Países com Mais Cartões Vermelhos na EURO", fontsize=14)
plt.xlabel("País", fontsize=12)
plt.ylabel("Número de Cartões Vermelhos", fontsize=12)
plt.xticks(rotation=45, fontsize=10)
plt.tight_layout()
plt.show()

# Gráfico 2: Cartões por posição
df_posicoes.plot(kind='bar', figsize=(12, 6), color='orange', edgecolor='black', legend=False)
plt.title("Cartões Vermelhos por Posição dos Jogadores na EURO", fontsize=14)
plt.xlabel("Posição", fontsize=12)
plt.ylabel("Número de Cartões Vermelhos", fontsize=12)
plt.xticks(rotation=45, fontsize=10)
plt.tight_layout()
plt.show()

# %% [markdown]
#   ### 1. Por que parecia ter menos cartões por país?
#
#   • No gráfico de países: O seu código usa  df_paises.head(10).plot(...) . Isso filtra apenas os 10 países com mais cartões vermelhos. A soma desses top 10 países dá exatamente 28 cartões.
#   • No gráfico de posições: O código plota o DataFrame  df_posicoes  inteiro (sem  .head(10) ). Como existem apenas 5 categorias de posições no dataset, o gráfico mostra todas elas, somando os 48 cartões totais.
#   • Se você somar a coluna  total_red_cards  inteira de ambos os DataFrames (sem limitar com  .head ), verá que ambas contam exatamente os mesmos 48 cartões vermelhos.

# %%
def processar_cartoes_vermelhos(red_cards_column):                                                                                                                                                                                                                                                        
    contador_paises = Counter()                                                                                                                                                                                                                                                                           
    contador_posicoes = Counter()                                                                                                                                                                                                                                                                         
    contador_jogadores = Counter()                                                                                                                                                                                                                                                                        
                                                                                                                                                                                                                                                                                                            
    for entry in red_cards_column:                                                                                                                                                                                                                                                                        
        if pd.isna(entry):                                                                                                                                                                                                                                                                                
            continue  # Ignorar NaNs                                                                                                                                                                                                                                                                      
                                                                                                                                                                                                                                                                                                            
        try:                                                                                                                                                                                                                                                                                              
            # Converter a string em uma lista de dicionários                                                                                                                                                                                                                                              
            cartoes = ast.literal_eval(entry)                                                                                                                                                                                                                                                             
            for cartao in cartoes:                                                                                                                                                                                                                                                                        
                # Contar por país                                                                                                                                                                                                                                                                         
                country_code = cartao.get('country_code', 'país não informado')                                                                                                                                                                                                                           
                contador_paises[country_code] += 1                                                                                                                                                                                                                                                        
                                                                                                                                                                                                                                                                                                            
                # Contar por posição (tratar string vazia como não informada)                                                                                                                                                                                                                             
                position = cartao.get('national_field_position', '')                                                                                                                                                                                                                                      
                if position == '':                                                                                                                                                                                                                                                                        
                    position = 'posição não informada'                                                                                                                                                                                                                                                    
                contador_posicoes[position] += 1                                                                                                                                                                                                                                                          
                                                                                                                                                                                                                                                                                                            
                # Contar por jogador (que estava faltando no seu código anterior)                                                                                                                                                                                                                         
                jogador = cartao.get('international_name', 'jogador não informado')                                                                                                                                                                                                                       
                contador_jogadores[jogador] += 1                                                                                                                                                                                                                                                          
                                                                                                                                                                                                                                                                                                            
        except (ValueError, SyntaxError):                                                                                                                                                                                                                                                                 
            continue  # Ignorar entradas inválidas                                                                                                                                                                                                                                                        
                                                                                                                                                                                                                                                                                                            
    return contador_paises, contador_posicoes, contador_jogadores                                                                                                                                                                                                                                         
                                                                                                                                                                                                                                                                                                            
#### Substitua a célula de Plotagem de Gráficos por:                                                                                                                                                                                                                                                        
                                                                                                                                                                                                                                                                                                            
euro_data['red_cards'] = euro_data['red_cards'].fillna("[]")  # Substituir NaN por uma lista vazia                                                                                                                                                                                                        
cartoes_por_pais, cartoes_por_posicao, cartoes_por_jogador = processar_cartoes_vermelhos(euro_data['red_cards'])                                                                                                                                                                                          
                                                                                                                                                                                                                                                                                                            
# Transformar os resultados em DataFrames                                                                                                                                                                                                                                                                 
df_paises = pd.DataFrame.from_dict(cartoes_por_pais, orient='index', columns=['total_red_cards']).sort_values(by='total_red_cards', ascending=False)                                                                                                                                                      
df_posicoes = pd.DataFrame.from_dict(cartoes_por_posicao, orient='index', columns=['total_red_cards']).sort_values(by='total_red_cards', ascending=False)                                                                                                                                                 
                                                                                                                                                                                                                                                                                                            
# Linhas de debug para você conferir que as contagens agora batem 100%                                                                                                                                                                                                                                    
print(f"Total de cartões por país (base inteira): {df_paises['total_red_cards'].sum()}")                                                                                                                                                                                                                  
print(f"Total de cartões por posição (base inteira): {df_posicoes['total_red_cards'].sum()}")                                                                                                                                                                                                             
                                                                                                                                                                                                                                                                                                            
# Gráfico 1: Cartões por país (exibindo todos os países para ver a soma de 48)
df_paises.plot(kind='bar', figsize=(12, 6), color='red', edgecolor='black', legend=False) 
plt.title("Cartões Vermelhos por País na EURO", fontsize=14)
plt.xlabel("País", fontsize=12)
plt.ylabel("Número de Cartões Vermelhos", fontsize=12)
plt.xticks(rotation=45, fontsize=10)
plt.tight_layout()
plt.show()

# Gráfico 2: Cartões por posição
df_posicoes.plot(kind='bar', figsize=(12, 6), color='orange', edgecolor='black', legend=False)
plt.title("Cartões Vermelhos por Posição dos Jogadores na EURO", fontsize=14)
plt.xlabel("Posição", fontsize=12)
plt.ylabel("Número de Cartões Vermelhos", fontsize=12)
plt.xticks(rotation=45, fontsize=10)
plt.tight_layout()
plt.show()
# Out:
# Total de cartões por país (base inteira): 48
# Total de cartões por posição (base inteira): 48

# %% [markdown]
# # Vices

# %%
# Filtrar as partidas finais (cópia explícita para evitar o copy warning)
# Ignorar o jogo empatado de 1968 (winner NaN), que foi decidido no jogo de desempate
finais = euro_data[(euro_data['round'] == 'FINAL') & euro_data['winner'].notna()].copy()

# Identificar os vice-campeões (times que jogaram na final, mas não venceram)
finais.loc[:, 'loser'] = finais.apply(
    lambda row: row['home_team'] if row['away_team'] == row['winner'] else row['away_team'],
    axis=1
)

# Contar os vice-campeões
vice_campeoes = finais['loser'].value_counts()

# Criar um dicionário para armazenar os anos de vice-campeonatos por time (em ordem)
anos_vices = finais.groupby('loser')['year'].apply(sorted)

# Visualizar os resultados com os anos no gráfico
plt.figure(figsize=(12, 6))
bars = plt.bar(vice_campeoes.index, vice_campeoes.values, color='gold', edgecolor='black')

# Ajustar o limite superior do gráfico para acomodar os anos
plt.ylim(0, vice_campeoes.max() + 2)

# Adicionar os anos de vice-campeonato como rótulos nas barras
for bar, team in zip(bars, vice_campeoes.index):
    anos_texto = ', '.join(map(str, anos_vices[team]))
    plt.text(
        bar.get_x() + bar.get_width() / 2,  # Centralizar o texto na barra
        bar.get_height() + 0.2,  # Posicionar logo acima da barra
        anos_texto,
        ha='center', va='bottom', fontsize=10, rotation=45  # Rotacionar texto em 45 graus
    )

# Ajustar o gráfico
plt.title("Times Mais Vice-Campeões da EURO (com Anos)", fontsize=14)
plt.xlabel("Time", fontsize=12)
plt.ylabel("Número de Vices", fontsize=12)
plt.xticks(rotation=45, fontsize=10)
plt.tight_layout()
plt.show()

# %%
# 1. Análise de Desempenho em Finais
# Filtrar as partidas finais
finais = euro_data[euro_data['round'] == 'FINAL']

# Contar finais jogadas por time: uma linha por (ano, time), sem duplicar
# a final de 1968 (empate + jogo de desempate)
participacoes = pd.concat([
    finais[['year', 'home_team']].rename(columns={'home_team': 'team'}),
    finais[['year', 'away_team']].rename(columns={'away_team': 'team'})
]).drop_duplicates()
finais_jogadas = participacoes['team'].value_counts()

# Contar vitórias em finais (o jogo empatado de 1968 tem winner NaN e é ignorado)
vitorias_finais = finais['winner'].value_counts()

# Combinar as duas contagens para criar uma análise completa
desempenho_finais = pd.DataFrame({
    'finais_jogadas': finais_jogadas,
    'vitorias_finais': vitorias_finais
}).fillna(0).astype(int)

# Adicionar uma coluna de derrotas em finais
desempenho_finais['derrotas_finais'] = desempenho_finais['finais_jogadas'] - desempenho_finais['vitorias_finais']

# Exibir a tabela de desempenho em finais
print("Desempenho em Finais:")
print(desempenho_finais.sort_values(by=['vitorias_finais', 'finais_jogadas'], ascending=False))

# Gráfico de desempenho em finais: vitórias + derrotas empilhadas = finais jogadas
desempenho_finais.sort_values(by='finais_jogadas', ascending=False)[['vitorias_finais', 'derrotas_finais']].plot(
    kind='bar',
    figsize=(12, 6),
    stacked=True,
    color=['gold', 'red'],
    edgecolor='black'
)
plt.title("Desempenho em Finais da EURO", fontsize=14)
plt.xlabel("Seleção", fontsize=12)
plt.ylabel("Número de Finais", fontsize=12)
plt.legend(['Vitórias', 'Derrotas'], loc='upper right')
plt.xticks(rotation=45, fontsize=10)
plt.tight_layout()
plt.show()
# Out:
# Desempenho em Finais:
#                 finais_jogadas  vitorias_finais  derrotas_finais
# Spain                  5               4                1
# Italy                  4               2                2
# France                 3               2                1
# West Germany           3               2                1
# USSR                   4               1                3
# Germany                3               1                2
# Portugal               2               1                1
# Czechoslovakia         1               1                0
# Denmark                1               1                0
# Greece                 1               1                0
# Netherlands            1               1                0
# England                2               0                2
# Yugoslavia             2               0                2
# Belgium                1               0                1
# Czechia                1               0                1
